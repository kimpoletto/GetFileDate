# %%
import os
import shutil
import pandas as pd
import time

# %%
diretorio = r'C:\Users\kimge\Pictures\EditAGOLBanner\Monitoramento de pessoas e veículs\MONITOR'
count = 0
for roots, dirs, files in os.walk(diretorio):
    for file in files:
        count += 1
        
        ti = os.path.getmtime(f'{roots}\\{file}')
        
        x = time.ctime(ti)
        
        if x[4:7] == 'Jun':
            mes = '06'
            print(mes)
        
        elif x[4:7] == 'Jul':
            mes = '07'
            print(mes)
        
            
        elif x[4:7] == 'Ago':
            mes = '08'
            print(mes)
            
            
        elif x[4:7] == 'Set':
            mes = '09'
            print(mes)
            
        elif x[4:7] == 'Out':
            mes = '10'
            print(mes)
            
        elif x[4:7] == 'Nov':
            mes = '11'
            print(mes)
        
        elif x[4:7] == 'Dez':
            mes = '12'
            print(mes)
        
            
        elif x[4:7] == 'Jan':
            mes = '01'
            print(mes)
            
            
        elif x[4:7] == 'Fev':
            mes = '02'
            print(mes)
            
        elif x[4:7] == 'Mar':
            mes = '03'
            print(mes)
            
        elif x[4:7] == 'Abr':
            mes = '10'
            print(mes)
            
        elif x[4:7] == 'Mai':
            mes = '05'
            print(mes)
            
        ano = x[-4:]
        
        print(ano)
            
        print(x)
        
print(count)
# Out:
# 07
# 2021
# Wed Jul 14 12:59:00 2021
# 07
# 2021
# Wed Jul 14 12:59:00 2021
# 07
# 2021
# Wed Jul 14 12:59:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# Wed Jul 14 13:00:00 2021
# 07
# 2021
# ...

# %%
print(x[4:7])
# Out:
# Jun

# %%
type(x)
# Out:
# str
